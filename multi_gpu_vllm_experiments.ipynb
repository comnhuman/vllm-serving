# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
    print("현재 기본 GPU index:", torch.cuda.current_device())
    print("현재 기본 GPU 이름:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("CUDA를 사용할 수 없습니다. 드라이버/설치 상태를 확인하세요.")
# Out:
# PyTorch version: 2.8.0+cu128
# CUDA available: True
# CUDA version: 12.8
# 현재 기본 GPU index: 0
# 현재 기본 GPU 이름: NVIDIA RTX A6000

# %%
import torch

if not torch.cuda.is_available():
    print("CUDA 사용 불가")
else:
    num_gpus = torch.cuda.device_count()
    print(f"사용 가능한 GPU 개수: {num_gpus}")
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# 사용 가능한 GPU 개수: 2
# GPU 0: NVIDIA RTX A6000
# GPU 1: NVIDIA RTX A6000

# %%
type(torch.cuda.device_count())
# Out:
# int

# %%
from tqdm import tqdm
import time

for i in tqdm(range(50)):
    time.sleep(0.1)
# Out:
# 100%|██████████| 50/50 [00:05<00:00,  9.90it/s]
